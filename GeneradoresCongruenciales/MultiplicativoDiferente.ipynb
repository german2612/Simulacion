# %%
import sys
from matplotlib.pylab import hist, show

a=3 #Constante Multiplicativa definida en 3
xo=0
c=0
m=0
cantidad=0
datos=[]
 
def Operaciones(a,xo,c,m,cantidad):
    print 'n   Xo   (aXo + c) modm   Xn + 1   Numero Rectangular '
    for i in range (0,cantidad,1):
        i += 1
        div = ((a * xo) + c)/m
        mod = ((a*xo)+c)%m
        nr = float((mod+.0) / (m+.0))
        print "%d   %d     %d  +   %d/%d      %d        %f  "%(i, xo, div, mod, m, mod, nr)
        xo = mod
        datos.append(nr)
    hist(datos,cantidad, (0,1))
    show()

def main():

    xo= int (raw_input("Ingrese valor de semilla inicial "))
    c = int (raw_input("Ingrese valor de constante aditiva "))
    m = int (raw_input("Ingrese valor de modulo "))
    cantidad = int(input("Cantidad: "))
    xoinicial = xo
    Operaciones(a,xo,c,m,cantidad)

if __name__ == "__main__":
    main()
# Out:
# Ingrese valor de semilla inicial 6
# Ingrese valor de constante aditiva 5
# Cantidad: 100
# Ingrese valor de modulo 16
# n   Xo   (aXo + c) modm   Xn + 1   Numero Rectangular
# 1   6     1  +   7/16      7        0.437500
# 2   7     1  +   10/16      10        0.625000
# 3   10     2  +   3/16      3        0.187500
# 4   3     0  +   14/16      14        0.875000
# 5   14     2  +   15/16      15        0.937500
# 6   15     3  +   2/16      2        0.125000
# 7   2     0  +   11/16      11        0.687500
# 8   11     2  +   6/16      6        0.375000
# 9   6     1  +   7/16      7        0.437500
# 10   7     1  +   10/16      10        0.625000
# 11   10     2  +   3/16      3        0.187500
# 12   3     0  +   14/16      14        0.875000
# 13   14     2  +   15/16      15        0.937500
# 14   15     3  +   2/16      2        0.125000
# 15   2     0  +   11/16      11        0.687500
# 16   11     2  +   6/16      6        0.375000
# 17   6     1  +   7/16      7        0.437500
# 18   7     1  +   10/16      10        0.625000
# 19   10     2  +   3/16      3        0.187500
# 20   3     0  +   14/16      14        0.875000
# 21   14     2  +   15/16      15        0.937500
# 22   15     3  +   2/16      2        0.125000
# 23   2     0  +   11/16      11        0.687500
# 24   11     2  +   6/16      6        0.375000
# 25   6     1  +   7/16      7        0.437500
# 26   7     1  +   10/16      10        0.625000
# 27   10     2  +   3/16      3        0.187500
# 28   3     0  +   14/16      14        0.875000
# 29   14     2  +   15/16      15        0.937500
# 30   15     3  +   2/16      2        0.125000
# 31   2     0  +   11/16      11        0.687500
# 32   11     2  +   6/16      6        0.375000
# 33   6     1  +   7/16      7        0.437500
# 34   7     1  +   10/16      10        0.625000
# 35   10     2  +   3/16      3        0.187500
# 36   3     0  +   14/16      14        0.875000
# 37   14     2  +   15/16      15        0.937500
